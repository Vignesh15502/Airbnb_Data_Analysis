# %%
import pymongo
import pandas as pd
pd.set_option("display.max_columns",None)
import warnings
warnings.filterwarnings("ignore")

# %%
Client= pymongo.MongoClient("mongodb+srv://vignesh:vigneshd@vignesh.vrsd7ro.mongodb.net/?retryWrites=true&w=majority")

db= Client["sample_airbnb"]
coll= db["listingsAndReviews"]

# %%
data= []

for i in coll.find({},{"_id":1, "listing_url":1, "name":1, 'property_type':1, 'room_type':1, 'bed_type':1, 'minimum_nights':1, 'maximum_nights':1, 'cancellation_policy':1, 'accommodates':1, 'bedrooms':1, 'beds':1, 'number_of_reviews':1, 'bathrooms':1, 'price':1, 'extra_people':1, 'guests_included':1, 'images.picture_url':1, 'review_scores':1,'cleaning_fee':1}):
    data.append(i)

# %%
data

# %%
df_1= pd.DataFrame(data)

# %%
df_1.head()
# Out:
#         _id                            listing_url  \
# 0  10066928  https://www.airbnb.com/rooms/10066928
# 1  10021707  https://www.airbnb.com/rooms/10021707
# 2  10009999  https://www.airbnb.com/rooms/10009999
# 3  10006546  https://www.airbnb.com/rooms/10006546
# 4  10059244  https://www.airbnb.com/rooms/10059244
#
#                                                name property_type  \
# 0                    3 chambres au coeur du Plateau     Apartment
# 1                          Private Room in Bushwick     Apartment
# 2                      Horto flat with small garden     Apartment
# 3                           Ribeira Charming Duplex         House
# 4  Ligne verte - à 15 min de métro du centre ville.     Apartment
#
#          room_type  bed_type minimum_nights maximum_nights  \
# 0  Entire home/apt  Real Bed              1           1125
# 1     Private room  Real Bed             14           1125
# 2  Entire home/apt  Real Bed              2           1125
# 3  Entire home/apt  Real Bed              2             30
# 4  Entire home/apt  Real Bed              2           1125
#
#   cancellation_policy  accommodates  bedrooms  beds  number_of_reviews  \
# 0            flexible             6       3.0   3.0                  0
# 1            flexible             1       1.0   1.0                  1
# 2            flexible             4       1.0   2.0                  0
# 3            moderate             8       3.0   5.0                 51
# 4            moderate             2       0.0   1.0                  0
#
#   bathrooms   price extra_people guests_included  \
# 0       1.0  140.00         0.00               1
# 1       1.5   40.00         0.00               1
# 2       1.0  317.00         0.00               1
# 3       1.0   80.00        15.00               6
# 4       1.0   43.00        12.00               1
#
#                                               images  \
# 0  {'picture_url': 'https://a0.muscache.com/im/pi...
# 1  {'picture_url': 'https://a0.muscache.com/im/pi...
# 2  {'picture_url': 'https://a0.muscache.com/im/pi...
# 3  {'picture_url': 'https://a0.muscache.com/im/pi...
# 4  {'picture_url': 'https://a0.muscache.com/im/pi...
#
#                                        review_scores cleaning_fee
# 0                                                 {}          NaN
# 1  {'review_scores_accuracy': 10, 'review_scores_...          NaN
# 2                                                 {}       187.00
# 3  {'review_scores_accuracy': 9, 'review_scores_c...        35.00
# 4                                                 {}          NaN

# %%
df_1["images"]= df_1["images"].apply(lambda x: x["picture_url"])

# %%
df_1["review_scores"]= df_1["review_scores"].apply(lambda x: x.get("review_scores_rating",0))

# %%
df_1.describe().T
# Out:
#                     count       mean        std  min  25%   50%   75%    max
# accommodates       5555.0   3.505851   2.297019  1.0  2.0   3.0   4.0   16.0
# bedrooms           5550.0   1.411712   1.041942  0.0  1.0   1.0   2.0   20.0
# beds               5542.0   2.071454   1.619660  0.0  1.0   2.0   3.0   25.0
# number_of_reviews  5555.0  27.606481  49.798376  0.0  1.0   5.0  32.0  533.0
# review_scores      5555.0  68.395680  41.829834  0.0  0.0  92.0  98.0  100.0

# %%
df_1.isnull().sum()
# Out:
# _id                       0
# listing_url               0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# cleaning_fee           1531
# dtype: int64

# %% [markdown]
# # *Handling the Null Vaulues*

# %%
# The Null Values Feauturs are 
#beds                     
#bedrooms                  
#bathrooms                
#cleaning_fee

# %%
df_1["beds"].fillna(0,inplace= True)
df_1["bedrooms"].fillna(0,inplace= True)
df_1["bathrooms"].fillna(0,inplace= True)
df_1["cleaning_fee"].fillna(0,inplace= True)

# %%
df_1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# cleaning_fee           0
# dtype: int64

# %%
# All Null Values are Cleared

# %% [markdown]
# # *Handling the DataTypes*

# %%
df_1.head(2)
# Out:
#         _id                            listing_url  \
# 0  10066928  https://www.airbnb.com/rooms/10066928
# 1  10021707  https://www.airbnb.com/rooms/10021707
#
#                              name property_type        room_type  bed_type  \
# 0  3 chambres au coeur du Plateau     Apartment  Entire home/apt  Real Bed
# 1        Private Room in Bushwick     Apartment     Private room  Real Bed
#
#   minimum_nights maximum_nights cancellation_policy  accommodates  bedrooms  \
# 0              1           1125            flexible             6       3.0
# 1             14           1125            flexible             1       1.0
#
#    beds  number_of_reviews bathrooms   price extra_people guests_included  \
# 0   3.0                  0       1.0  140.00         0.00               1
# 1   1.0                  1       1.5   40.00         0.00               1
#
#                                               images  review_scores  \
# 0  https://a0.muscache.com/im/pictures/f208bdd7-b...              0
# 1  https://a0.muscache.com/im/pictures/72844c8c-f...            100
#
#   cleaning_fee
# 0            0
# 1            0

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# price                   object
# extra_people            object
# guests_included         object
# images                  object
# review_scores            int64
# cleaning_fee            object
# dtype: object

# %%
df_1["minimum_nights"]= df_1["minimum_nights"].astype(int)
df_1["maximum_nights"]= df_1["maximum_nights"].astype(int)
df_1["bedrooms"]= df_1["bedrooms"].astype(int)
df_1["beds"]= df_1["beds"].astype(int)
df_1["bathrooms"]= df_1["bathrooms"].astype(str).astype(float).astype(int)
df_1["price"]= df_1["price"].astype(str).astype(float).astype(int)
df_1["extra_people"]= df_1["extra_people"].astype(str).astype(float).astype(int)
df_1["guests_included"]= df_1["guests_included"].astype(str).astype(float).astype(int)
df_1["cleaning_fee"]= df_1["cleaning_fee"].astype(str).astype(float).astype(int)

# %%
df_1.dtypes
# Out:
# _id                    object
# listing_url            object
# name                   object
# property_type          object
# room_type              object
# bed_type               object
# minimum_nights          int32
# maximum_nights          int32
# cancellation_policy    object
# accommodates            int64
# bedrooms                int32
# beds                    int32
# number_of_reviews       int64
# bathrooms               int32
# price                   int32
# extra_people            int32
# guests_included         int32
# images                 object
# review_scores           int64
# cleaning_fee            int32
# dtype: object

# %% [markdown]
# # *Collect the Host Details*

# %%
host= []
for i in coll.find({},{"_id":1, "host":1}):
    host.append(i)

# %%
host

# %%
df_host= pd.DataFrame(host)

# %%
host_columns= {'_id':[],'host_id':[], 'host_url':[], 'host_name':[], 'host_location':[],"host_response_time":[], 'host_thumbnail_url':[], 'host_picture_url':[], 'host_neighbourhood':[], 'host_response_rate':[], 'host_is_superhost':[], 'host_has_profile_pic':[], 'host_identity_verified':[], 'host_listings_count':[], 'host_total_listings_count':[], 'host_verifications':[]}

for i in df_host["_id"]:
    host_columns["_id"].append(i)
for i in df_host["host"]:
    host_columns["host_id"].append(i["host_id"])
    host_columns["host_url"].append(i["host_url"])
    host_columns["host_name"].append(i["host_name"])
    host_columns["host_location"].append(i["host_location"])
    host_columns["host_response_time"].append(i.get("host_response_time"))
    host_columns["host_thumbnail_url"].append(i["host_thumbnail_url"])
    host_columns["host_picture_url"].append(i["host_picture_url"])
    host_columns["host_neighbourhood"].append(i["host_neighbourhood"])
    host_columns["host_response_rate"].append(i.get("host_response_rate"))
    host_columns["host_is_superhost"].append(i["host_is_superhost"])
    host_columns["host_has_profile_pic"].append(i["host_has_profile_pic"])
    host_columns["host_identity_verified"].append(i["host_identity_verified"])
    host_columns["host_listings_count"].append(i["host_listings_count"])
    host_columns["host_total_listings_count"].append(i["host_total_listings_count"])
    host_columns["host_verifications"].append(i["host_verifications"])

# %%
df_host_1= pd.DataFrame(host_columns)

# %%
df_host_1.head(2)
# Out:
#         _id   host_id                                    host_url host_name  \
# 0  10066928   9036477   https://www.airbnb.com/users/show/9036477   Margaux
# 1  10021707  11275734  https://www.airbnb.com/users/show/11275734      Josh
#
#                        host_location host_response_time  \
# 0           Montreal, Quebec, Canada               None
# 1  New York, New York, United States               None
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/9036477/profi...
# 1  https://a0.muscache.com/im/users/11275734/prof...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/9036477/profi...         Le Plateau
# 1  https://a0.muscache.com/im/users/11275734/prof...           Bushwick
#
#    host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                 NaN              False                  True
# 1                 NaN              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                   False                    2                          2
# 1                    True                    1                          1
#
#                     host_verifications
# 0  [email, phone, reviews, work_email]
# 1         [email, phone, reviews, kba]

# %%
df_host_1.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %% [markdown]
# # *Checking the "host_neighbourhood" details*

# %%
# host_neighbourhood have more empty values ('')
# Finding the how many values are empty
list_index= []
for index,row in df_host_1.iterrows():
    if row["host_neighbourhood"] =='':
        list_index.append(index)

# %%
len(list_index)
# Out:
# 1923

# %%
# "host_neighbourhood" have a "1923" empty values ('')
# so we want to replace thet empty values

# %% [markdown]
# # *Handling the Null values and empty values for "host"*

# %%
df_host_1["host_response_time"].fillna("Not Specified",inplace= True)
df_host_1["host_response_rate"].fillna("Not Specified",inplace= True)
df_host_1["host_neighbourhood"]= df_host_1["host_neighbourhood"].replace({'':"Not Specified"})

# %%
df_host_1.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df_host_1
# Out:
#            _id   host_id                                    host_url  \
# 0     10066928   9036477   https://www.airbnb.com/users/show/9036477
# 1     10021707  11275734  https://www.airbnb.com/users/show/11275734
# 2     10009999   1282196   https://www.airbnb.com/users/show/1282196
# 3     10006546  51399391  https://www.airbnb.com/users/show/51399391
# 4     10059244   7140229   https://www.airbnb.com/users/show/7140229
# ...        ...       ...                                         ...
# 5550   9799412  27207511  https://www.airbnb.com/users/show/27207511
# 5551   9887054  31386255  https://www.airbnb.com/users/show/31386255
# 5552   9895628  14856657  https://www.airbnb.com/users/show/14856657
# 5553   9981541  51289938  https://www.airbnb.com/users/show/51289938
# 5554   9983221  37776205  https://www.airbnb.com/users/show/37776205
#
#         host_name                                    host_location  \
# 0         Margaux                         Montreal, Quebec, Canada
# 1            Josh                New York, New York, United States
# 2           Ynaie  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3     Ana&Gonçalo                  Porto, Porto District, Portugal
# 4            Caro                         Montreal, Quebec, Canada
# ...           ...                                              ...
# 5550        Gokay                                 Istanbul, Turkey
# 5551          Cat                                        Hong Kong
# 5552          Mah                      Rio, Rio de Janeiro, Brazil
# 5553          Ken                                        Hong Kong
# 5554          Ana                                         Portugal
#
#      host_response_time                                 host_thumbnail_url  \
# 0         Not Specified  https://a0.muscache.com/im/users/9036477/profi...
# 1         Not Specified  https://a0.muscache.com/im/users/11275734/prof...
# 2         Not Specified  https://a0.muscache.com/im/pictures/9681e3cc-4...
# 3        within an hour  https://a0.muscache.com/im/pictures/fab79f25-2...
# 4        within an hour  https://a0.muscache.com/im/pictures/user/c6477...
# ...                 ...                                                ...
# 5550       within a day  https://a0.muscache.com/im/users/27207511/prof...
# 5551       within a day  https://a0.muscache.com/im/pictures/965f2c12-5...
# 5552      Not Specified  https://a0.muscache.com/im/users/14856657/prof...
# 5553     within an hour  https://a0.muscache.com/im/pictures/48ba1de1-b...
# 5554     within an hour  https://a0.muscache.com/im/users/37776205/prof...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/users/9036477/profi...         Le Plateau
# 1     https://a0.muscache.com/im/users/11275734/prof...           Bushwick
# 2     https://a0.muscache.com/im/pictures/9681e3cc-4...    Jardim Botânico
# 3     https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 4     https://a0.muscache.com/im/pictures/user/c6477...      Not Specified
# ...                                                 ...                ...
# 5550  https://a0.muscache.com/im/users/27207511/prof...        Sultanahmet
# 5551  https://a0.muscache.com/im/pictures/965f2c12-5...       Causeway Bay
# 5552  https://a0.muscache.com/im/users/14856657/prof...    Jardim Botânico
# 5553  https://a0.muscache.com/im/pictures/48ba1de1-b...             Jordan
# 5554  https://a0.muscache.com/im/users/37776205/prof...      Not Specified
#
#      host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0         Not Specified              False                  True
# 1         Not Specified              False                  True
# 2         Not Specified              False                  True
# 3                 100.0              False                  True
# 4                 100.0              False                  True
# ...                 ...                ...                   ...
# 5550               50.0              False                  True
# 5551               60.0              False                  True
# 5552      Not Specified              False                  True
# 5553               90.0              False                  True
# 5554              100.0               True                  True
#
#       host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                      False                    2                          2
# 1                       True                    1                          1
# 2                      False                    1                          1
# 3                       True                    3                          3
# 4                      False                    1                          1
# ...                      ...                  ...                        ...
# 5550                   False                    2                          2
# 5551                   False                    7                          7
# 5552                   False                    1                          1
# 5553                   False                    6                          6
# 5554                   False                    8                          8
#
#                                      host_verifications
# 0                   [email, phone, reviews, work_email]
# 1                          [email, phone, reviews, kba]
# 2                              [email, phone, facebook]
# 3     [email, phone, reviews, jumio, offline_governm...
# 4         [email, phone, reviews, jumio, government_id]
# ...                                                 ...
# 5550                            [email, phone, reviews]
# 5551                            [email, phone, reviews]
# 5552                            [email, phone, reviews]
# 5553                    [email, phone, google, reviews]
# 5554  [email, phone, reviews, offline_government_id,...
#
# [5555 rows x 16 columns]

# %%
# Changing the "True" or "False" features

df_host_1["host_is_superhost"]= df_host_1["host_is_superhost"].map({False: "No", True: "Yes"})
df_host_1["host_has_profile_pic"]= df_host_1["host_has_profile_pic"].map({False: "No", True: "Yes"})
df_host_1["host_identity_verified"]= df_host_1["host_identity_verified"].map({False: "No", True: "Yes"})

# %%
df_host_1.head()
# Out:
#         _id   host_id                                    host_url  \
# 0  10066928   9036477   https://www.airbnb.com/users/show/9036477
# 1  10021707  11275734  https://www.airbnb.com/users/show/11275734
# 2  10009999   1282196   https://www.airbnb.com/users/show/1282196
# 3  10006546  51399391  https://www.airbnb.com/users/show/51399391
# 4  10059244   7140229   https://www.airbnb.com/users/show/7140229
#
#      host_name                                    host_location  \
# 0      Margaux                         Montreal, Quebec, Canada
# 1         Josh                New York, New York, United States
# 2        Ynaie  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3  Ana&Gonçalo                  Porto, Porto District, Portugal
# 4         Caro                         Montreal, Quebec, Canada
#
#   host_response_time                                 host_thumbnail_url  \
# 0      Not Specified  https://a0.muscache.com/im/users/9036477/profi...
# 1      Not Specified  https://a0.muscache.com/im/users/11275734/prof...
# 2      Not Specified  https://a0.muscache.com/im/pictures/9681e3cc-4...
# 3     within an hour  https://a0.muscache.com/im/pictures/fab79f25-2...
# 4     within an hour  https://a0.muscache.com/im/pictures/user/c6477...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/9036477/profi...         Le Plateau
# 1  https://a0.muscache.com/im/users/11275734/prof...           Bushwick
# 2  https://a0.muscache.com/im/pictures/9681e3cc-4...    Jardim Botânico
# 3  https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 4  https://a0.muscache.com/im/pictures/user/c6477...      Not Specified
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0      Not Specified                No                  Yes
# 1      Not Specified                No                  Yes
# 2      Not Specified                No                  Yes
# 3              100.0                No                  Yes
# 4              100.0                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                     No                    2                          2
# 1                    Yes                    1                          1
# 2                     No                    1                          1
# 3                    Yes                    3                          3
# 4                     No                    1                          1
#
#                                   host_verifications
# 0                [email, phone, reviews, work_email]
# 1                       [email, phone, reviews, kba]
# 2                           [email, phone, facebook]
# 3  [email, phone, reviews, jumio, offline_governm...
# 4      [email, phone, reviews, jumio, government_id]

# %% [markdown]
# # *Collect the Address Details*

# %%
address= []
for i in coll.find({}, {"_id":1, "address":1}):
    address.append(i)

# %%
df_address= pd.DataFrame(address)

# %%
address_columns= {'_id':[], 'street':[], 'suburb':[], 'government_area':[], 'market':[], 'country':[],
                   'country_code':[], 'location_type':[], "longitude":[], "latitude":[],
                    "is_location_exact":[]}

for i in df_address["_id"]:
    address_columns["_id"].append(i)

for i in df_address["address"]:
    address_columns["street"].append(i["street"])
    address_columns["suburb"].append(i["suburb"])
    address_columns["government_area"].append(i["government_area"])
    address_columns["market"].append(i["market"])
    address_columns["country"].append(i["country"])
    address_columns["country_code"].append(i["country_code"])
    address_columns["location_type"].append(i["location"]["type"])
    address_columns["longitude"].append(i["location"]["coordinates"][0])
    address_columns["latitude"].append(i["location"]["coordinates"][1])
    address_columns["is_location_exact"].append(i["location"]["is_location_exact"])

# %%
df_address_1= pd.DataFrame(address_columns)

# %%
df_address_1.head(3)
# Out:
#         _id                                  street                 suburb  \
# 0  10066928                Montréal, Québec, Canada  Le Plateau-Mont-Royal
# 1  10021707             Brooklyn, NY, United States               Brooklyn
# 2  10009999  Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
#
#          government_area          market        country country_code  \
# 0  Le Plateau-Mont-Royal        Montreal         Canada           CA
# 1               Bushwick        New York  United States           US
# 2        Jardim Botânico  Rio De Janeiro         Brazil           BR
#
#   location_type  longitude   latitude  is_location_exact
# 0         Point  -73.57383  45.522330               True
# 1         Point  -73.93615  40.697910               True
# 2         Point  -43.23075 -22.966254               True

# %%
df_address_1.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
# Checking the empty values ('') for all features

#for i in df_address_1.columns:
id_e=[]
stre_e=[]
suburb_e=[]
gov_e=[]
mark_e=[]
cntry_e=[]
cntry_co_e=[]
loc_ty_e=[]
long_e=[]
lat_e=[]
is_loc_tr_e=[]
for index,row in df_address_1.iterrows():
    if row["_id"] == '':
        id_e.append(index)

    if row["street"] == '':
        stre_e.append(index)
        
    if row["suburb"] == '':
        suburb_e.append(index)

    if row["government_area"] == '':
        gov_e.append(index)

    if row["market"] == '':
        mark_e.append(index)

    if row["country"] == '':
        cntry_e.append(index)
    
    if row["country_code"] == '':
        cntry_co_e.append(index)

    if row["location_type"] == '':
        loc_ty_e.append(index) 

    if row["longitude"] == '':
        long_e.append(index)

    if row["latitude"] == '':
        lat_e.append(index)

    if row["is_location_exact"] == '':
        is_loc_tr_e.append(index)

# %%
empty_columns=[id_e,stre_e,suburb_e,gov_e,mark_e,cntry_e,cntry_co_e,loc_ty_e,long_e,lat_e,is_loc_tr_e]
for i in empty_columns:
    print(len(i))
# Out:
# 0
# 0
# 887
# 0
# 6
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# # *Handling the empty values  and Boolian Values*

# %%
# "suburb" and "market" have a empty values

df_address_1["suburb"]= df_address_1["suburb"].replace({'':"Not Specified"})
df_address_1["market"]= df_address_1["market"].replace({'':"Not Specified"})

df_address_1["is_location_exact"]= df_address_1["is_location_exact"].map({False:"No", True:"Yes"})

# %%
df_address_1
# Out:
#            _id                                  street                 suburb  \
# 0     10066928                Montréal, Québec, Canada  Le Plateau-Mont-Royal
# 1     10021707             Brooklyn, NY, United States               Brooklyn
# 2     10009999  Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
# 3     10006546                  Porto, Porto, Portugal          Not Specified
# 4     10059244                Montréal, Québec, Canada  Hochelaga-Maisonneuve
# ...        ...                                     ...                    ...
# 5550   9799412                 Fatih, İstanbul, Turkey                  Fatih
# 5551   9887054  Hong Kong, Hong Kong Island, Hong Kong             Quarry Bay
# 5552   9895628  Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
# 5553   9981541           Hong Kong, Kowloon, Hong Kong          Yau Tsim Mong
# 5554   9983221                  Porto, Porto, Portugal          Not Specified
#
#                                         government_area          market  \
# 0                                 Le Plateau-Mont-Royal        Montreal
# 1                                              Bushwick        New York
# 2                                       Jardim Botânico  Rio De Janeiro
# 3     Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 4                         Mercier-Hochelaga-Maisonneuve        Montreal
# ...                                                 ...             ...
# 5550                                              Fatih        Istanbul
# 5551                                            Eastern       Hong Kong
# 5552                                    Jardim Botânico  Rio De Janeiro
# 5553                                      Yau Tsim Mong       Hong Kong
# 5554  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
#
#             country country_code location_type   longitude   latitude  \
# 0            Canada           CA         Point  -73.573830  45.522330
# 1     United States           US         Point  -73.936150  40.697910
# 2            Brazil           BR         Point  -43.230750 -22.966254
# 3          Portugal           PT         Point   -8.613080  41.141300
# 4            Canada           CA         Point  -73.549490  45.545480
# ...             ...          ...           ...         ...        ...
# 5550         Turkey           TR         Point   28.979890  41.006000
# 5551      Hong Kong           HK         Point  114.207220  22.291570
# 5552         Brazil           BR         Point  -43.220452 -22.963607
# 5553      Hong Kong           HK         Point  114.173200  22.303810
# 5554       Portugal           PT         Point   -8.616930  41.151370
#
#      is_location_exact
# 0                  Yes
# 1                  Yes
# 2                  Yes
# 3                   No
# 4                   No
# ...                ...
# 5550                No
# 5551                No
# 5552               Yes
# 5553               Yes
# 5554                No
#
# [5555 rows x 11 columns]

# %% [markdown]
# # **Availability**

# %%
availability= []
for i in coll.find({}, {"_id":1, "availability":1}):
    availability.append(i)

# %%
df_availabe= pd.DataFrame(availability)

# %%
availabe_columns= {'_id':[], 'availability_30':[], 'availability_60':[], 'availability_90':[], 'availability_365':[]}

for i in df_availabe["_id"]:
    availabe_columns["_id"].append(i)

for i in df_availabe["availability"]:
    availabe_columns["availability_30"].append(i["availability_30"])
    availabe_columns["availability_60"].append(i["availability_60"])
    availabe_columns["availability_90"].append(i["availability_90"])
    availabe_columns["availability_365"].append(i["availability_365"])

# %%
df_availabe_1= pd.DataFrame(availabe_columns)

# %%
df_availabe_1
# Out:
#            _id  availability_30  availability_60  availability_90  \
# 0     10066928                0                0                0
# 1     10021707                0                0                0
# 2     10009999                0                0                0
# 3     10006546               28               47               74
# 4     10059244                0                0                0
# ...        ...              ...              ...              ...
# 5550   9799412               30               60               90
# 5551   9887054               18               48               78
# 5552   9895628                0                0                0
# 5553   9981541               30               60               90
# 5554   9983221               26               51               77
#
#       availability_365
# 0                    0
# 1                    0
# 2                    0
# 3                  239
# 4                   32
# ...                ...
# 5550               365
# 5551               353
# 5552                 0
# 5553               365
# 5554               300
#
# [5555 rows x 5 columns]

# %%
df_availabe_1.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_availabe_1.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %% [markdown]
# # *Collecting the Amenities*

# %%
amenities= []
for i in coll.find({},{"_id":1, "amenities":1}):
    amenities.append(i)

# %%
df_amenities= pd.DataFrame(amenities)

# %%
def sort_amenities(x):
    a= x
    a.sort()
    return a

# %%
df_amenities["amenities"]= df_amenities["amenities"].apply(lambda x: sort_amenities(x))

# %%
df_amenities
# Out:
#            _id                                          amenities
# 0     10066928  [Dryer, Essentials, Family/kid friendly, Hair ...
# 1     10021707  [Air conditioning, Buzzer/wireless intercom, C...
# 2     10009999  [Buzzer/wireless intercom, Essentials, Family/...
# 3     10006546  [Bed linens, Buzzer/wireless intercom, Cable T...
# 4     10059244  [Bed linens, Essentials, Free parking on premi...
# ...        ...                                                ...
# 5550   9799412  [24-hour check-in, Air conditioning, Breakfast...
# 5551   9887054  [24-hour check-in, Air conditioning, Elevator,...
# 5552   9895628  [Air conditioning, Buzzer/wireless intercom, C...
# 5553   9981541  [Air conditioning, Elevator, Fire extinguisher...
# 5554   9983221  [Bed linens, Cable TV, Cleaning before checkou...
#
# [5555 rows x 2 columns]

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.dtypes
# Out:
# _id          object
# amenities    object
# dtype: object

# %% [markdown]
# # *Merging the All DataFrames*

# %%
#df_1
#df_host_1
#df_address_1
#df_availabe_1
#df_amenities
df= pd.merge(df_1, df_host_1, on="_id")
df= pd.merge(df, df_address_1, on="_id")
df= pd.merge(df, df_availabe_1, on="_id")
df= pd.merge(df, df_amenities, on="_id")

# %%
# save the file 
# df.to_csv("Airbnb.csv", index= False)

# %%
df= pd.read_csv("C:/Users/vignesh/Desktop/New folder/Airbnb.csv")

# %%
df
# Out:
#            _id                            listing_url  \
# 0     10066928  https://www.airbnb.com/rooms/10066928
# 1     10021707  https://www.airbnb.com/rooms/10021707
# 2     10009999  https://www.airbnb.com/rooms/10009999
# 3     10006546  https://www.airbnb.com/rooms/10006546
# 4     10059244  https://www.airbnb.com/rooms/10059244
# ...        ...                                    ...
# 5550   9799412   https://www.airbnb.com/rooms/9799412
# 5551   9887054   https://www.airbnb.com/rooms/9887054
# 5552   9895628   https://www.airbnb.com/rooms/9895628
# 5553   9981541   https://www.airbnb.com/rooms/9981541
# 5554   9983221   https://www.airbnb.com/rooms/9983221
#
#                                                   name      property_type  \
# 0                       3 chambres au coeur du Plateau          Apartment
# 1                             Private Room in Bushwick          Apartment
# 2                         Horto flat with small garden          Apartment
# 3                              Ribeira Charming Duplex              House
# 4     Ligne verte - à 15 min de métro du centre ville.          Apartment
# ...                                                ...                ...
# 5550                            Byzantium Suites Hotel  Bed and breakfast
# 5551               Quarry Bay fully furnished studio C          Apartment
# 5552               Duplex com vista para o J. Botanico          Apartment
# 5553                         Economy 2-beds room (308)          Apartment
# 5554                     Cozy apartment downtown Porto          Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0     Entire home/apt  Real Bed               1            1125
# 1        Private room  Real Bed              14            1125
# 2     Entire home/apt  Real Bed               2            1125
# 3     Entire home/apt  Real Bed               2              30
# 4     Entire home/apt  Real Bed               2            1125
# ...               ...       ...             ...             ...
# 5550     Private room  Real Bed               1            1125
# 5551     Private room  Real Bed               3            1125
# 5552  Entire home/apt  Real Bed               5            1125
# 5553     Private room  Real Bed               1            1125
# 5554  Entire home/apt  Real Bed               3            1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0                        flexible             6         3     3
# 1                        flexible             1         1     1
# 2                        flexible             4         1     2
# 3                        moderate             8         3     5
# 4                        moderate             2         0     1
# ...                           ...           ...       ...   ...
# 5550                     flexible             2         1     2
# 5551                     flexible             1         1     1
# 5552                     flexible             8         2     2
# 5553  strict_14_with_grace_period             2         1     2
# 5554  strict_14_with_grace_period             4         1     2
#
#       number_of_reviews  bathrooms  price  extra_people  guests_included  \
# 0                     0          1    140             0                1
# 1                     1          1     40             0                1
# 2                     0          1    317             0                1
# 3                    51          1     80            15                6
# 4                     0          1     43            12                1
# ...                 ...        ...    ...           ...              ...
# 5550                  3          1    269             0                1
# 5551                  4          1    400           300                2
# 5552                  1          3    701             0                1
# 5553                  3          0    322           150                2
# 5554                107          1     58            15                2
#
#                                                  images  review_scores  \
# 0     https://a0.muscache.com/im/pictures/f208bdd7-b...              0
# 1     https://a0.muscache.com/im/pictures/72844c8c-f...            100
# 2     https://a0.muscache.com/im/pictures/5b408b9e-4...              0
# 3     https://a0.muscache.com/im/pictures/e83e702f-e...             89
# 4     https://a0.muscache.com/im/pictures/af5c069c-e...              0
# ...                                                 ...            ...
# 5550  https://a0.muscache.com/im/pictures/25c8c363-a...            100
# 5551  https://a0.muscache.com/im/pictures/a39e3f36-9...             85
# 5552  https://a0.muscache.com/im/pictures/55e7014a-6...            100
# 5553  https://a0.muscache.com/im/pictures/87f82e28-1...             80
# 5554  https://a0.muscache.com/im/pictures/15b74c6a-8...             98
#
#       cleaning_fee   host_id                                    host_url  \
# 0                0   9036477   https://www.airbnb.com/users/show/9036477
# 1                0  11275734  https://www.airbnb.com/users/show/11275734
# 2              187   1282196   https://www.airbnb.com/users/show/1282196
# 3               35  51399391  https://www.airbnb.com/users/show/51399391
# 4                0   7140229   https://www.airbnb.com/users/show/7140229
# ...            ...       ...                                         ...
# 5550             0  27207511  https://www.airbnb.com/users/show/27207511
# 5551             0  31386255  https://www.airbnb.com/users/show/31386255
# 5552           200  14856657  https://www.airbnb.com/users/show/14856657
# 5553             0  51289938  https://www.airbnb.com/users/show/51289938
# 5554            20  37776205  https://www.airbnb.com/users/show/37776205
#
#         host_name                                    host_location  \
# 0         Margaux                         Montreal, Quebec, Canada
# 1            Josh                New York, New York, United States
# 2           Ynaie  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3     Ana&Gonçalo                  Porto, Porto District, Portugal
# 4            Caro                         Montreal, Quebec, Canada
# ...           ...                                              ...
# 5550        Gokay                                 Istanbul, Turkey
# 5551          Cat                                        Hong Kong
# 5552          Mah                      Rio, Rio de Janeiro, Brazil
# 5553          Ken                                        Hong Kong
# 5554          Ana                                         Portugal
#
#      host_response_time                                 host_thumbnail_url  \
# 0         Not Specified  https://a0.muscache.com/im/users/9036477/profi...
# 1         Not Specified  https://a0.muscache.com/im/users/11275734/prof...
# 2         Not Specified  https://a0.muscache.com/im/pictures/9681e3cc-4...
# 3        within an hour  https://a0.muscache.com/im/pictures/fab79f25-2...
# 4        within an hour  https://a0.muscache.com/im/pictures/user/c6477...
# ...                 ...                                                ...
# 5550       within a day  https://a0.muscache.com/im/users/27207511/prof...
# 5551       within a day  https://a0.muscache.com/im/pictures/965f2c12-5...
# 5552      Not Specified  https://a0.muscache.com/im/users/14856657/prof...
# 5553     within an hour  https://a0.muscache.com/im/pictures/48ba1de1-b...
# 5554     within an hour  https://a0.muscache.com/im/users/37776205/prof...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/users/9036477/profi...         Le Plateau
# 1     https://a0.muscache.com/im/users/11275734/prof...           Bushwick
# 2     https://a0.muscache.com/im/pictures/9681e3cc-4...    Jardim Botânico
# 3     https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 4     https://a0.muscache.com/im/pictures/user/c6477...      Not Specified
# ...                                                 ...                ...
# 5550  https://a0.muscache.com/im/users/27207511/prof...        Sultanahmet
# 5551  https://a0.muscache.com/im/pictures/965f2c12-5...       Causeway Bay
# 5552  https://a0.muscache.com/im/users/14856657/prof...    Jardim Botânico
# 5553  https://a0.muscache.com/im/pictures/48ba1de1-b...             Jordan
# 5554  https://a0.muscache.com/im/users/37776205/prof...      Not Specified
#
#      host_response_rate host_is_superhost host_has_profile_pic  \
# 0         Not Specified                No                  Yes
# 1         Not Specified                No                  Yes
# 2         Not Specified                No                  Yes
# 3                 100.0                No                  Yes
# 4                 100.0                No                  Yes
# ...                 ...               ...                  ...
# 5550               50.0                No                  Yes
# 5551               60.0                No                  Yes
# 5552      Not Specified                No                  Yes
# 5553               90.0                No                  Yes
# 5554              100.0               Yes                  Yes
#
#      host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                        No                    2                          2
# 1                       Yes                    1                          1
# 2                        No                    1                          1
# 3                       Yes                    3                          3
# 4                        No                    1                          1
# ...                     ...                  ...                        ...
# 5550                     No                    2                          2
# 5551                     No                    7                          7
# 5552                     No                    1                          1
# 5553                     No                    6                          6
# 5554                     No                    8                          8
#
#                                      host_verifications  \
# 0           ['email', 'phone', 'reviews', 'work_email']
# 1                  ['email', 'phone', 'reviews', 'kba']
# 2                        ['email', 'phone', 'facebook']
# 3     ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 4     ['email', 'phone', 'reviews', 'jumio', 'govern...
# ...                                                 ...
# 5550                      ['email', 'phone', 'reviews']
# 5551                      ['email', 'phone', 'reviews']
# 5552                      ['email', 'phone', 'reviews']
# 5553            ['email', 'phone', 'google', 'reviews']
# 5554  ['email', 'phone', 'reviews', 'offline_governm...
#
#                                       street                 suburb  \
# 0                   Montréal, Québec, Canada  Le Plateau-Mont-Royal
# 1                Brooklyn, NY, United States               Brooklyn
# 2     Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
# 3                     Porto, Porto, Portugal          Not Specified
# 4                   Montréal, Québec, Canada  Hochelaga-Maisonneuve
# ...                                      ...                    ...
# 5550                 Fatih, İstanbul, Turkey                  Fatih
# 5551  Hong Kong, Hong Kong Island, Hong Kong             Quarry Bay
# 5552  Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
# 5553           Hong Kong, Kowloon, Hong Kong          Yau Tsim Mong
# 5554                  Porto, Porto, Portugal          Not Specified
#
#                                         government_area          market  \
# 0                                 Le Plateau-Mont-Royal        Montreal
# 1                                              Bushwick        New York
# 2                                       Jardim Botânico  Rio De Janeiro
# 3     Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 4                         Mercier-Hochelaga-Maisonneuve        Montreal
# ...                                                 ...             ...
# 5550                                              Fatih        Istanbul
# 5551                                            Eastern       Hong Kong
# 5552                                    Jardim Botânico  Rio De Janeiro
# 5553                                      Yau Tsim Mong       Hong Kong
# 5554  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
#
#             country country_code location_type   longitude   latitude  \
# 0            Canada           CA         Point  -73.573830  45.522330
# 1     United States           US         Point  -73.936150  40.697910
# 2            Brazil           BR         Point  -43.230750 -22.966254
# 3          Portugal           PT         Point   -8.613080  41.141300
# 4            Canada           CA         Point  -73.549490  45.545480
# ...             ...          ...           ...         ...        ...
# 5550         Turkey           TR         Point   28.979890  41.006000
# 5551      Hong Kong           HK         Point  114.207220  22.291570
# 5552         Brazil           BR         Point  -43.220452 -22.963607
# 5553      Hong Kong           HK         Point  114.173200  22.303810
# 5554       Portugal           PT         Point   -8.616930  41.151370
#
#      is_location_exact  availability_30  availability_60  availability_90  \
# 0                  Yes                0                0                0
# 1                  Yes                0                0                0
# 2                  Yes                0                0                0
# 3                   No               28               47               74
# 4                   No                0                0                0
# ...                ...              ...              ...              ...
# 5550                No               30               60               90
# 5551                No               18               48               78
# 5552               Yes                0                0                0
# 5553               Yes               30               60               90
# 5554                No               26               51               77
#
#       availability_365                                          amenities
# 0                    0  ['Dryer', 'Essentials', 'Family/kid friendly',...
# 1                    0  ['Air conditioning', 'Buzzer/wireless intercom...
# 2                    0  ['Buzzer/wireless intercom', 'Essentials', 'Fa...
# 3                  239  ['Bed linens', 'Buzzer/wireless intercom', 'Ca...
# 4                   32  ['Bed linens', 'Essentials', 'Free parking on ...
# ...                ...                                                ...
# 5550               365  ['24-hour check-in', 'Air conditioning', 'Brea...
# 5551               353  ['24-hour check-in', 'Air conditioning', 'Elev...
# 5552                 0  ['Air conditioning', 'Buzzer/wireless intercom...
# 5553               365  ['Air conditioning', 'Elevator', 'Fire extingu...
# 5554               300  ['Bed linens', 'Cable TV', 'Cleaning before ch...
#
# [5555 rows x 50 columns]
